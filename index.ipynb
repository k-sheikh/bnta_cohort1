# %% [markdown]
# # Bright Network Full Stack Web Dev Course
#
# - 12-week course, 5-day week, 8-hour day
# - Timing: 12 Weeks * 5 Days/Week → 60 Days
# - Python and JavaScript language code demos are provided as Jupyter Notebooks on GitHub
# - Web code demos are provided on GitHub, CodePen, CodeSandBox, and StackBlitz
# - Instructor provides live coaching sessions covering course content (lecture & demo)
# - Students will be assigned labs:
#   - Tutorials and Readings
#     - https://docs.python.org/3/tutorial
#     - https://en.wikibooks.org/wiki/Category:Book:Python_Programming
#     - https://www.learnpython.org
#     - https://developer.mozilla.org/en-US/docs/Web/JavaScript/A_re-introduction_to_JavaScript
#     - https://javascript.info
#     - https://eloquentjavascript.net
#     - http://speakingjs.com/es5
#     - https://realpython.com
#     - https://www.programiz.com/python-programming
#     - https://www.educative.io/courses/introduction-to-javascript-first-steps
#     - https://github.com/the-road-to-learn-react/the-road-to-learn-react
#     - https://en.wikibooks.org/wiki/Java_Programming
#     - https://www.vogella.com/tutorials/JavaIntroduction/article.html
#     - many more...
#   - Challenges on
#     - **hackerrank.com** https://www.hackerrank.com
#     - **exercism.io** https://exercism.io
#     - **leetcode.com** https://leetcode.com
#     - **edabit.com** https://edabit.com/challenges/python3
#     - **practicepython.org** https://www.practicepython.org
#   - Online readings (docs, blogs, tutorials, Wikipedia, etc.)
#   - Online tutorial activity assignments
#   - In-class teach-backs
#   - Mini projects (whiteboarding, coding, and presenting)
#   - Final capstone project (whiteboarding, coding, and presenting)
# - Students are encouraged to search the web and collaborate with each other to solve problems
# - Students are encouraged to build their personal code portfolio on GitHub, CodePen, hackerrank, exercism, etc.
# - Students are encouraged to ask questions, stay engaged, and keep up!
#
# **NOTE: Technical Skills, Independent Learning, and Collaboration** This course focuses on three distinct learning objectives. The first, and most obvious objective, is to develop practical software development technical skills. However, and perhaps even more importantly, this course strives to develop effective learning strategies and collaboration skills. The ultimate goal is not to learn a long list of detailed facts presented in class, but rather to become an effective life-long learner and a dependable team member. For this reason, you will be given homework assignments that are open-ended, requiring some interpretation, research, and diligence on your part. You are then expected to collaborate and share resources and knowledge that you have discovered with your fellow students. This feedback will be shared in class in the form of student teach-backs and presentations. This knowledge should also be shared outside of class on ```slack.com```. The instructor and all students should check ```slack.com``` at least once per day for updates. In addition to technical knowledge, independent learning and collaborative communication skills are important for SDEs in the real world.

# %% [markdown]
# ## Daily Routine (8 Hr)
#
# - ```09:00AM-09:30AM (00:30)``` Teach-Back & Q&A
# - ```09:30AM-12:00AM (02:30)``` Lectures, Breakouts, and Demos
# - ```12:00PM-02:00PM (02:00)``` Lunch
# - ```02:00PM-04:30PM (02:30)``` Labs
# - ```04:30PM-05:00PM (30 Min)``` Team wrap up

# %% [markdown]
# ## Developer Tools
#
# - **CPython** https://www.python.org
# - **Anaconda** https://www.anaconda.com
# - **Node** https://nodejs.org/en/docs
# - **Jupyter Notebooks** https://jupyter.org
# - **Git** https://git-scm.com/doc
# - **GitHub** https://github.com
# - **Docker** https://docs.docker.com
# - **Bash** https://devdocs.io/bash
# - **Visual Studio Code** https://code.visualstudio.com/docs
# - **CodePen** https://codepen.io
# - **CodeSandBox** https://codesandbox.io
# - **StackBlitz** https://stackblitz.com
# - **Babel** https://babeljs.io
# - **Webpack** https://webpack.js.org
# - **Slack** https://slack.com
# - **Trello** https://trello.com
# - **Jira** https://www.atlassian.com/software/jira

# %% [markdown]
# ## Internet Protocols
#
# - Internet Protocols: https://en.wikipedia.org/wiki/Internet_Protocol
# - HTTP/HTTPS: https://en.wikipedia.org/wiki/Hypertext_Transfer_Protocol
# - SSL/TLS: https://en.wikipedia.org/wiki/Transport_Layer_Security
# - TCP/IP: https://en.wikipedia.org/wiki/Internet_protocol_suite
# - DNS: https://en.wikipedia.org/wiki/Domain_Name_System

# %% [markdown]
# ## Google Style Guides
#
# - HTML/CSS Style Guide - https://google.github.io/styleguide/htmlcssguide.html
# - JavaScript Style Guide - https://google.github.io/styleguide/jsguide.html
# - Python Style Guide - https://google.github.io/styleguide/pyguide.html
# - Shell Style Guide - https://google.github.io/styleguide/shellguide.html
# - C++ Style Guide - https://google.github.io/styleguide/cppguide.html
# - C# Style Guide - https://google.github.io/styleguide/csharp-style.html
# - Swift Style Guide - https://google.github.io/swift
# - Objective-C Style Guide - https://google.github.io/styleguide/objcguide.html
# - Java Style Guide - https://google.github.io/styleguide/javaguide.html
# - R Style Guide - https://google.github.io/styleguide/Rguide.html
# - Go Style Guide - https://github.com/golang/go/wiki/CodeReviewComments
# - See: https://google.github.io/styleguide/htmlcssguide.html

# %% [markdown]
# ## Full Course Outline (12 Week * 5 Day/Week == 60 Day)
#
# * Welcome
#
#   * Welcome to Bright Network Technology Academy
#   * Technology set up (including downloading anything they need)
#   * Expectation setting and walkthrough of 12-week learning timetable
#   * Getting to know fellow cohort
#   * Soft-skills session on how to get the most from virtual training
#   * Course Logistics
#     * Bright Network Student Support Procedures and Contacts
#     * Attendance
#     * Participation
#     * In-Class Labs
#     * Homework Assignments
#     * Mini Projects and Presentations
#     * Final Capstone Project and Presentation

# %% [markdown]
# ### Part 1 - Collaboration
#
# * ```Day 1``` Software Development Survey
#
#   * [Agile](Day%201/Agile/index.ipynb)
#   * [Collaboration](Day%201/Collaboration/index.ipynb)
#
# * ```Day 2``` Dev Tools Survey
#
#   * [Git and GitHub](Day%201/Git/index.ipynb)
#   * [Bash](Day%201/Bash/index.ipynb)
#   * [Node](Day%201/Node/index.ipynb)
#   * [Visual Studio Code](Day%201/VSCode/index.ipynb)
#
#   * Online Collaboration and Research Survey
#
#     * [Codepen](https://codepen.io)
#     * [CodeSandBox](https://codesandbox.io)
#     * [StackBlitz](https://stackblitz.com)
#     * [Slack](https://slack.com)
#     * [Stack Overflow](https://stackoverflow.com)
#     * [Quora](https://www.quora.com)
#     * [Google Search](https://www.google.com)

# %% [markdown]
# ### Part 2 - Frontend foundation
#
# HTML, CSS3, Bootstrap, and Browser APIs Deep Dive ```(4 Days)```
#
#   * Day 3 - [HTML5](Day%203/HTML5/index.ipynb)
#   * Day 4 - [CSS3](Day%204/CSS3/index.ipynb)
#   * Day 5 - [JavaScript (Browser)](Day%205/JavaScriptBrowser/index.ipynb)
#   * Day 6 - [Bootstrap](Day%206/Bootstrap/index.ipynb)

# %% [markdown]
# ### Part 3 Imperative languages & JavaScript
#
# [JavaScript and Node](JavaScriptNode.ipynb) ```(7 Day)```
#
#   * Day 7 - [Getting started](Day%207/JavaScriptNode/JavaScript1of8.ipynb)
#   * Day 8 - [Data types](Day%208/JavaScriptNode/JavaScript2of8.ipynb)
#   * Day 9 - [Flow, Error handling, and Files](Day%209/JavaScriptNode/JavaScript3of8.ipynb)
#   * Day 10 - [Functions, Scope, Hoisting, and Funtional programming](Day%2010/JavaScriptNode/JavaScript4of8.ipynb)
#   * Day 11 - [Classes, Inheritance, Promises, and Closures](Day%2011/JavaScriptNode/JavaScript5of8.ipynb)
#   * Day 12 - [Modules, Assertions, JSON, Data structure and algorithms](Day%2012/JavaScriptNode/JavaScript6of8.ipynb)
#   * Day 13 - [Iterators, Generators, Regular expressions](Day%2013/JavaScriptNode/JavaScript7of8.ipynb)
#
# JavaScript Mini Project ```(2 Day)```
#
#   * Day 14-15 - [JavaScript Mini Project](Day%2014-15/JavaScriptNode/JavaScriptMiniProject.ipynb)
#
# TypeScript Survey ```(1 Day)```
#
#   * Day 16 - [TypeScript](Day%2016/TypeScript/index.ipynb)

# %% [markdown]
# ### Part 4 QA & XP
#
# Testing: Quality Assurance ```(1 Day)```
#   * Day 17 - [Testing: Quality Assurance (1 Day)](Day%2017/Testing/index.ipynb)
#
# Extreme Programming ```(1 Day)```
#   * Day 18 - [Extreme Programming](Day%2018/ExtremeProgramming/index.ipynb)

# %% [markdown]
# ### Part 5 Imperative languages and Python
#
# [Python 3 and SQL](Python3.ipynb) ```(6+1 = 7 Days)```
#
#   - Day 19 - [Getting started, Syntax, Expressions](Day%2019/Python3/PythonDay1of10.ipynb)
#   - Day 20 - *** First project of part 3 review ***
#   - Day 21 - [Functions](Day%2021/Python3/PythonDay2of10.ipynb)
#   - Day 22 - [Itertools and Decorators](Day%2022/Python3)
#   - Day 23 - [Control statements, Basic Data Structures and Algorithms](Day%2023/Python3/PythonDay4of10.ipynb)

# %% [markdown]
# ### Part 6 Server-Side Frameworks and Databases
#
# SQL ```(1+1 = 2 Days)```
#
#   - Day 24 - [SQL](Day%2024/SQL/index.ipynb)
#   - Day 25 - *** Continuation of Day 23 of part 5***
#
# Flask ```(5 Days)```
#
#   - Day 26 - SQLALchemy + Flask
#   - Day 27 - Flask Forms
#   - Day 28 - Flask API, REST, Authentication
#   - Day 29 - Intro to Django
#   - Day 30 - Data analysis for full stack devs
#
# Express and others ```(2 Days)``` (WIP)
#
#   * [Express](Express/index.ipynb)
#   * [MongoDB](MongoDB/index.ipynb) or Mongoose
#   * [Databases in JavaScript](JavaScriptNode/JavaScript8of8.ipynb)
#
# Server-Side Framework Mini Project and Presentation ```(5 Days)```

# %% [markdown]
# ### Part 7 Client-Side Web Frameworks
#
# WIP
#
#   * [React](React/index.ipynb) (2 Day)
#   * [Vue](Vue/index.ipynb) (1 Day)
#   * [Angular](Angular/index.ipynb) (1 Day)
#
# Client-Side React Mini Project and Presentation ```(5 Day)```

# %% [markdown]
# ### Part 8 Data Structures and Algorithms
#
# WIP (3 Days?)
#
#    1. ```1 Hr``` [Introduction](AlgorithmsDataStructures/Introduction.ipynb)
#    2. ```3 Hr``` [Algorithms](AlgorithmsDataStructures/Algorithms.ipynb)
#    3. ```3 Hr``` [Data Structures](AlgorithmsDataStructures/DataStructures.ipynb)
#    4. ```30 Min``` [Mathematical Topics (optional)](AlgorithmsDataStructures/MathematicalTopics.ipynb)
#    5. ```30 Min``` [Esoteric Topics (optional)](AlgorithmsDataStructures/EsotericTopics.ipynb)

# %% [markdown]
# ### Part 9 Capstone Project
#
# Capstone Project and Presentation ```(7 Days)```

# %% [markdown]
# ### Extra material:
#
#   * [Python 3 - Multi-threading](Extra/Python3.Multithreading/PythonMultithreading.ipynb)
#   * [Python 3 - Scientific Analysis](Extra/Python3.ScientificAnalysis/PythonDay9of10.ipynb)
#   * [Python 3 - Simulations](Extra/Python3.Simulations/PythonDay7of10.ipynb)
#   * [Python 3 - Statistics](Extra/Python3.Statistics/PythonDay5of10.ipynb)
#   * [Python 3 - Various](Extra/Python3.Various/PythonDay10of10.ipynb)
#   * [Docker](Extra/Docker/index.ipynb)
#   * [Java](Extra/Java/index.ipynb) ```(1 Day)```
#   * [Mobile App Dev](Extra/MobileAppDev/index.ipynb) ```(1 Day)```

# %% [markdown]
# ## Learning Resources
#
# - Tools
#
#   - [Agile (atlassian)](https://www.atlassian.com/agile)
#   - [Scrum (atlassian)](https://www.atlassian.com/agile/scrum)
#   - [Scrum Guide](https://scrumguides.org/docs/scrumguide/v2020/2020-Scrum-Guide-US.pdf)
#   - [Kanban Guide](https://kanbanguides.org/html-kanban-guide)
#   - [Kanban (atlassian)](https://www.atlassian.com/agile/kanban)
#   - [Bash Docs](https://www.gnu.org/software/bash/manual/bash.html)
#   - [Bash Tutorial](https://www.freecodecamp.org/news/linux-command-line-bash-tutorial)
#   - [Docker Docs](https://docs.docker.com/get-started/overview)
#   - [Docker Tutorial](https://www.docker.com/play-with-docker)
#   - [Node]()
#   - [GitHub]()
#   - [Git Docs](https://git-scm.com/docs)
#   - [Git Tutorial](https://git-scm.com/docs/gittutorial)
#   - [Visual Studio Code](https://code.visualstudio.com/docs)
#   - [Figma](https://www.figma.com)
#   - [Lucidchart](https://www.lucidchart.com/pages)
#   - [Moqup](https://moqups.com)
#
# - HTML, CSS3, Bootstrap, and Browser APIs
#
#   - [W3C HTML 5.2 W3C Recommendation](https://www.w3.org/TR/html52)
#   - [DevDocs.io](https://devdocs.io)
#   - [MDN Web Docs](5https://developer.mozilla.org/en-US/docs/Web)
#   - [W3C: Cascading Style Sheets](https://www.w3.org/Style/CSS/Overview.en.html)
#   - [CSS: Cascading Style Sheets](https://developer.mozilla.org/en-US/docs/Web/CSS)
#   - [DOM Docs](https://developer.mozilla.org/en-US/docs/Web/API/Document_Object_Model)
#   - [DOM Enlightenment](http://domenlightenment.com)
#   - [AJAX](https://developer.mozilla.org/en-US/docs/Web/Guide/AJAX)
#   - [XMLHttpRequest](https://developer.mozilla.org/en-US/docs/Web/API/XMLHttpRequest)
#   - [Fetch](https://developer.mozilla.org/en-US/docs/Web/API/Fetch_API)
#   - [Axios](https://www.npmjs.com/package/axios)
#   - [Bootstrap](https://getbootstrap.com)
#
# - JavaScript
#
#   - [JavaScript Docs](https://developer.mozilla.org/en-US/docs/Web/JavaScript)
#   - [JavaScript Reintroduction](https://developer.mozilla.org/en-US/docs/Web/JavaScript/A_re-introduction_to_JavaScript)
#   - [JavaScript Tutorial](https://javascript.info)
#   - [Eloquent JavaScript](https://eloquentjavascript.net)
#   - [Exploring ES6](https://exploringjs.com/es6/index.html)
#   - [Speaking JavaScript](http://speakingjs.com/es5/index.html)
#
# - Client-Side Frameworks
#
#   - [React Docs](https://reactjs.org/docs/getting-started.html)
#   - [React Tutorial](https://reactjs.org/tutorial/tutorial.html)
#   - [React/Redux](https://react-redux.js.org/introduction/basic-tutorial)
#   - [Angular Docs](https://angular.io/docs)
#   - [Tour of Heroes App and Tutorial](https://angular.io/tutorial)
#   - [Vue Docs](https://vuejs.org/v2/guide)
#   - [Vue Docs](https://vuejs.org/v2/guide/installation.html)
#   - [Vue Tutorial](https://developer.mozilla.org/en-US/docs/Learn/Tools_and_testing/Client-side_JavaScript_frameworks/Vue_getting_started)
#
# - Python3
#
#   - [Python3 Docs](https://docs.python.org/3)
#   - [Python3 Tutorial](https://docs.python.org/3/tutorial)
#   - [Guide to Python](https://docs.python-guide.org)
#   - [Think Python](http://www.greenteapress.com/thinkpython/thinkpython.pdf)
#
# - SQL
#
#   - [SQL (Wikipedia)](https://en.wikipedia.org/wiki/SQL)
#   - [SQL Tutorial](https://www.datacamp.com/courses/introduction-to-sql)
#
# - Server-Side Frameworks
#
#   - [Flask Docs](https://flask.palletsprojects.com/en/1.1.x)
#   - [Flask Tutorial](https://flask.palletsprojects.com/en/1.0.x/tutorial)
#   - [Django Docs](https://docs.djangoproject.com/en/3.1)
#   - [Django Tutorial](https://docs.djangoproject.com/en/3.1/intro)
#   - [Express Docs](https://developer.mozilla.org/en-US/docs/Learn/Server-side/Express_Nodejs)
#   - [Express Tutorial](https://developer.mozilla.org/en-US/docs/Learn/Server-side/Express_Nodejs/Introduction)
#
# - Mobile
#
#   - [Android Docs](https://developer.android.com/docs)
#   - [iOS](https://developer.apple.com/ios/)
#   - [Ionic](https://ionicframework.com)
#
# - General
#   - [futureproof](https://github.com/getfutureproof/fp_guides_wiki)

# %% [markdown]
# ## Advanced Self-Study Topics (optional)
#
# - **Web3.js** https://web3js.readthedocs.io
# - **WebAssembly** https://webassembly.org
# - **Blockchain** https://en.wikipedia.org/wiki/Blockchain
# - **Machine Learning** https://en.wikipedia.org/wiki/Machine_learning
# - **Algorithms and Data Structures** https://en.wikipedia.org/wiki/Category:Algorithms_and_data_structures
# - **Design Patterns** https://en.wikipedia.org/wiki/Design_Patterns
# - **Programming Languages** https://en.wikipedia.org/wiki/List_of_programming_languages_by_type
# - **Cloud Computing: AWS, Azure, GCP** https://en.wikipedia.org/wiki/Cloud_computing
# - **Project Management Tools: Maven, Jira, Jenkins, Ansible, etc.**  https://en.wikipedia.org/wiki/Comparison_of_project_management_software
# - **Communication Protocols: TCP/IP, HTTPS, etc.** https://en.wikipedia.org/wiki/Communication_protocol
# - **Secure Coding** https://en.wikipedia.org/wiki/Secure_coding
