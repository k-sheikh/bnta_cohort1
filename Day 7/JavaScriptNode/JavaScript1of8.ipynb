// %% [markdown]
// # JavaScript Day 1 of 8
//
// - Getting Started
// - NodeJS and NPM
// - Fundamental Syntax
// - Data Types and Variables
// - Operators and Expressions
// - Twilio

// %% [markdown]
// ## Pre-Read Assignment
//
// - Read: https://nodejs.dev/learn
// - Be prepared for in-class discussion on the reading assignment

// %% [markdown]
// ## Daily Schedule
//
// ### 08:00AM-08:30AM (30 Min) Stand-Up and Teach-Back
//
// Search for web articles, tutorials, and documentation for answers to the following questions and then discuss:
//
// 1. Where would you find the official documentation on JavaScript?
// 2. What do you need to run JavaScript?
// 3. What can JavaScript be used for?
// 4. How is JavaScript similar or different to other programming languages?
// 5. What are JavaScript reserved keywords?
// 6. What are JavaScript arithmetic operators?
// 7. What are JavaScript variables?
// 8. What are JavaScript functions?
// 9. How does JavaScript syntax use semicolons, parenthesis, curly brackets, and white space?
// 10. What is recursion?
// 11. What is object-oriented programming and how does JavaScript implement object orientation?
// 12. What is the difference between dynamic typing and static typing?
// 13. What is an algorithm?
// 14. What is a list?
// 15. What is a tuple?
// 16. What is a map?
// 17. Does JavaScript support multi-threading?
// 18. What is asynchronous code
// 19. What is ```npm```?
// 20. What is ES?
//
// ### 08:30AM-10:00AM (90 Min) Lectures and Demos
//
// #### Lectures
//
// 1. Node Setup: https://developer.mozilla.org/en-US/docs/Learn/Server-side/Express_Nodejs/development_environment
// 2. Demonstrate: Installing Node (students should follow along)
// 3. Review a selection of glossary: https://www.codecademy.com/articles/glossary-javascript
// 4. Demonstrate code examples from The JavaScript Tutorial: https://javascript.info
// 5. Introduce JavaScript Language Reference: https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference
// 6. A Beginner’s Guide to ```npm```: https://www.sitepoint.com/npm-guide/
// 7. Cheat Sheet: https://www.codecademy.com/learn/introduction-to-javascript/modules/learn-javascript-introduction/cheatsheet
// 8. JavaScript Data Types: https://developer.mozilla.org/en-US/docs/Web/JavaScript/Data_structures
// 9. JavaScript Syntax: https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Lexical_grammar
// 10. Node.js tutorial in Visual Studio Code: https://code.visualstudio.com/docs/nodejs/nodejs-tutorial
//
// #### Demos
//
// 1. Try the **bubbleSort** example: https://flaviocopes.com (can use https://repl.it/languages/nodejs or your local Node.JS)
// 2. [Getting Started](GettingStarted.ipynb)
// 3. [NodeJS and NPM](NodeJSandNPM.ipynb)
// 4. [Fundamental Syntax](FundamentalSyntax.ipynb)
// 5. [Data Types and Variables](DataTypesVariables.ipynb)
// 6. [Operators and Expressions](OperatorsExpressions.ipynb)
//
// ### 10:00AM-10:30AM (30 Min) Q&A
//
// - Students
//   - Students ask and answer their own questions as independently as possible
//   - Students actively research answers to other student's questions in real time if possible
//   - Students actively participate in dialog as much as possible
// - Instructor
//   - Instructor promotes exploration of concepts with thought provoking questions
//   - Instructor provides active guidance when necessary, but mostly acts as a facilitator
//   - Instructor actively corrects misunderstandings as required
//
// ### 10:30AM-10:45AM (15 Min) Break
//
// - Instructor and students must return on time to avoid falling behind in schedule.
//
// ### 10:45AM-12:00PM (75 Min) Lab
//
// **NOTE**: As usual, there will be topics that we did not discuss in lecture that you will most likely want to make use of in this lab. Be prepared to google search as necessary, or ask questions in class during the lab to resolve any issues. At this point in the class, it is not required that you use any advanced syntax, however, you may use any language features that you like. In most cases, your code in this lab will be fairly simple. You can easily find and copy/paste code you find on the web without the need of deep understanding. As is the case in real work world, the key is to see how resourceful you can become in resolving issues as they come up.
//
// 1. Try the JavaScript tutorial at: https://nodeschool.io/#workshoppers
// 2. Try the JavaScript code examples at: https://www.programiz.com/javascript/examples
//
// ### 12:00PM-01:00PM (60 Min) Lunch
//
// - Instructor and students must return on time to avoid falling behind in schedule.
//
// ### 01:00PM-02:45PM (105 Min) Lab
//
// - Explore JavaScript further by writing code using any combination of the following online coding exercises:
//
// - Online Code Challenges:
//
//   - [hackerrank.com](https://www.hackerrank.com)
//   - [exercism.io](https://exercism.io/my/tracks)
//   - [leetcode.com](https://leetcode.com)
//   - Search for others and if you find a good one, share it with the class)
//
// - Interactive JavaScript Exercises and Tutorials:
//
//   - [Learn JS](https://www.learn-js.org)
//
// - Try copying and pasting and modifying code examples from various online JavaScript books:
//
//   - [Eloquent JavaScript](https://eloquentjavascript.net)
//   - [Speaking JavaScript](http://speakingjs.com/es5/index.html)
//   - [JavaScript for Impatient Programmers](https://exploringjs.com/impatient-js)
//   - [Exploring ES6](https://exploringjs.com/es6.html)
//   - [The Modern JavaScript Tutorial](https://javascript.info)
//   - [Learn JavaScript](https://gitbookio.gitbooks.io/javascript)
//   - [JavaScript Garden](https://bonsaiden.github.io/JavaScript-Garden)
//   - [JavaScript Allongé](https://leanpub.com/javascript-allonge/read)
//   - [Learning JavaScript Design Patterns](https://addyosmani.com/resources/essentialjsdesignpatterns/book)
//   - [Understanding ECMAScript 6](https://leanpub.com/understandinges6/read)
//   - [Human JavaScript](http://read.humanjavascript.com)
//   - [MDN JavaScript Docs](https://developer.mozilla.org/en-US/docs/Web/JavaScript)
//   - [Mozilla reintroduction to JS tutorial](https://developer.mozilla.org/en-US/docs/Web/JavaScript/A_re-introduction_to_JavaScrip)
//   - [freeCodeCamp: Introduction to JavaScript](https://www.freecodecamp.org/learn/javascript-algorithms-and-data-structures/basic-javascript)
//   - [freeCodeCamp: Introduction to the ES6 Challenges](https://www.freecodecamp.org/learn/javascript-algorithms-and-data-structures/es6)
//   - [Introduction to Node.js](https://nodejs.dev)
//   - [NodeJSNotesForProfessionals](https://books.goalkicker.com/NodeJSBook/NodeJSNotesForProfessionals.pdf)
//
// - For advanced students, try the following code tutorial:
//
//   - * [HTML 5 Shoot 'em Up in an Afternoon](https://leanpub.com/html5shootemupinanafternoon/read)
//
// ### 02:45PM-03:00PM (15 Min) Break
//
// - Instructor and students must return on time to avoid falling behind in schedule.
//
// ### 03:00PM-03:30PM (30 Min) Lab Discussion and Teach-Back
//
// - Ask questions in class
// - Present your code in class
//
// ### 03:30PM-04:00PM (30 Min) Homework Assignment
//
// 1. Try out the Twilio starter tutorial: https://www.twilio.com/docs/voice/quickstart/node
// 2. View the video (a bit long but you can skim through at double speed): https://www.youtube.com/watch?v=PkZNo7MFNFg
// 3. Make notes on your questions and discoveries as you read the content
// 4. Write a Python program that prompts for two integers and then calculates and displays the GCD
// 5. Be prepared to present these questions and discoveries in class the next day
